# %% [markdown]
# # Andrew Hwang / Week1 Homework / Sep. 13. 24

# %% [markdown]
# ### Dataset 1: Boston 311

# %%
# Import libraries

import pandas as pd
# %matplotlib inline

# %%
url = 'https://data.boston.gov/dataset/8048697b-ad64-4bfc-b090-ee00169f2323/resource/6ff6a6fd-3141-4440-a880-6f60a37fe789/download/tmpcv_10m2s.csv'

# %%
boston311 = pd.read_csv(url)
# Out:
# /var/folders/5h/1y1pgqkj59ndm5pn7srvhkyh0000gn/T/ipykernel_3442/672975855.py:1: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   boston311 = pd.read_csv(url)

# %%
boston311.head()
# Out:
#    case_enquiry_id              open_dt        sla_target_dt  \
# 0     101003148265  2020-01-01 00:07:00  2020-01-13 03:30:00
# 1     101003148266  2020-01-01 00:54:48  2020-01-01 00:54:48
# 2     101003148268  2020-01-01 01:14:13  2020-01-03 03:30:00
# 3     101003148269  2020-01-01 01:19:00  2020-01-03 03:30:00
# 4     101003148271  2020-01-01 02:02:00  2020-01-03 03:30:00
#
#              closed_dt  on_time case_status  \
# 0  2020-01-20 06:43:10  OVERDUE      Closed
# 1  2020-01-02 01:11:49  OVERDUE      Closed
# 2  2020-01-01 10:05:46   ONTIME      Closed
# 3  2020-01-02 01:10:56   ONTIME      Closed
# 4  2020-01-01 02:07:17   ONTIME      Closed
#
#                                       closure_reason  \
# 0  Case Closed. Closed date : 2020-01-20 11:43:10...
# 1  Case Closed. Closed date : 2020-01-02 06:11:49...
# 2  Case Closed. Closed date : 2020-01-01 15:05:46...
# 3  Case Closed. Closed date : 2020-01-02 06:10:56...
# 4  Case Closed. Closed date : 2020-01-01 07:07:17...
#
# ...

# %%
boston311.columns
# Out:
# Index(['case_enquiry_id', 'open_dt', 'sla_target_dt', 'closed_dt', 'on_time',
#        'case_status', 'closure_reason', 'case_title', 'subject', 'reason',
#        'type', 'queue', 'department', 'submitted_photo', 'closed_photo',
#        'location', 'fire_district', 'pwd_district', 'city_council_district',
#        'police_district', 'neighborhood', 'neighborhood_services_district',
#        'ward', 'precinct', 'location_street_name', 'location_zipcode',
#        'latitude', 'longitude', 'geom_4326', 'source'],
#       dtype='object')

# %%
len(boston311)
# Out:
# 251222

# %%
boston311.describe()
# Out:
#        case_enquiry_id  location_zipcode       latitude      longitude
# count     2.512220e+05     196540.000000  249132.000000  249132.000000
# mean      1.010034e+11       2126.905887      42.324363     -71.081205
# std       1.221636e+05         17.836674       0.455815       0.455745
# min       1.010031e+11       2108.000000     -71.135810     -71.190497
# 25%       1.010033e+11       2119.000000      42.299046     -71.105288
# 50%       1.010034e+11       2126.000000      42.333261     -71.075641
# 75%       1.010035e+11       2130.000000      42.350642     -71.058860
# max       1.010038e+11       2467.000000      42.398393      42.358474

# %%
boston311.subject.unique()
# Out:
# array(['Parks & Recreation Department',
#        'Transportation - Traffic Division', 'Public Works Department',
#        "Mayor's 24 Hour Hotline", 'Inspectional Services',
#        'Property Management', 'Animal Control',
#        'Boston Water & Sewer Commission', 'Boston Police Department',
#        'Consumer Affairs & Licensing', 'Neighborhood Services'],
#       dtype=object)

# %%
len(boston311.subject.unique())
# Out:
# 11

# %%
len(boston311.reason.unique())
# Out:
# 45

# %%
len(boston311.type.unique())
# Out:
# 175

# %%
boston311['subject'].value_counts()
# Out:
# subject
# Public Works Department              131098
# Transportation - Traffic Division     54561
# Inspectional Services                 21363
# Mayor's 24 Hour Hotline               18248
# Parks & Recreation Department         17355
# Property Management                    3487
# Animal Control                         3239
# Boston Water & Sewer Commission        1220
# Boston Police Department                589
# Neighborhood Services                    36
# Consumer Affairs & Licensing             26
# Name: count, dtype: int64

# %%
boston311['subject'].value_counts() / len(boston311) * 100
# Out:
# subject
# Public Works Department              52.184124
# Transportation - Traffic Division    21.718241
# Inspectional Services                 8.503634
# Mayor's 24 Hour Hotline               7.263695
# Parks & Recreation Department         6.908233
# Property Management                   1.388015
# Animal Control                        1.289298
# Boston Water & Sewer Commission       0.485626
# Boston Police Department              0.234454
# Neighborhood Services                 0.014330
# Consumer Affairs & Licensing          0.010349
# Name: count, dtype: float64

# %%
boston311[['subject','case_enquiry_id']].groupby(by=['subject']).count().sort_values(by='case_enquiry_id', ascending=False)
# Out:
#                                    case_enquiry_id
# subject
# Public Works Department                     131098
# Transportation - Traffic Division            54561
# Inspectional Services                        21363
# Mayor's 24 Hour Hotline                      18248
# Parks & Recreation Department                17355
# Property Management                           3487
# Animal Control                                3239
# Boston Water & Sewer Commission               1220
# Boston Police Department                       589
# Neighborhood Services                           36
# Consumer Affairs & Licensing                    26

# %%
boston311[['subject','case_enquiry_id']].groupby(by=['subject']).count().sort_values(by='case_enquiry_id', ascending=False).plot.bar()
# Out:
# <Axes: xlabel='subject'>

# %% [markdown]
# ### Dataset 2: Real estate sales

# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
year=2015; boro='brooklyn'

# %%
fname=str(year)+'_'+boro+'.xls'

# %%
url = 'https://www1.nyc.gov/assets/finance/downloads/pdf/rolling_sales/annualized-sales/'+str(year)+\
                                                                                       '/'+fname

# %%
re_sales = pd.read_excel(url)

# %%
re_sales.head()
# Out:
#   BROOKLYN ANNUALIZE SALE FOR 2015.  (All Sales From  January 1, 2015 - December 31, 2015)  \
# 0  Sales File as of 3/31/2016.  Coop Sales Files ...
# 1  Neighborhood Name 4/1/16.  Descriptive Data as...
# 2  Building Class Category is based on Building C...
# 3                                          BOROUGH\n
# 4                                                  3
#
#                   Unnamed: 1                                    Unnamed: 2  \
# 0                        NaN                                           NaN
# 1                        NaN                                           NaN
# 2                        NaN                                           NaN
# 3             NEIGHBORHOOD\n                     BUILDING CLASS CATEGORY\n
# 4  BATH BEACH                 01  ONE FAMILY DWELLINGS
#
#                Unnamed: 3 Unnamed: 4 Unnamed: 5   Unnamed: 6  \
# 0                     NaN        NaN        NaN          NaN
# ...

# %%
import urllib
dataDir = ''
urllib.request.urlretrieve(url, dataDir + fname)
# Out:
# ('2015_brooklyn.xls', <http.client.HTTPMessage at 0x151240e90>)

# %%
re_sales = pd.read_excel(dataDir + fname, skiprows = 4)

# %%
re_sales.head()
# Out:
#    BOROUGH\n             NEIGHBORHOOD\n  \
# 0          3  BATH BEACH
# 1          3  BATH BEACH
# 2          3  BATH BEACH
# 3          3  BATH BEACH
# 4          3  BATH BEACH
#
#                       BUILDING CLASS CATEGORY\n TAX CLASS AT PRESENT\n  \
# 0  01  ONE FAMILY DWELLINGS                                          1
# 1  01  ONE FAMILY DWELLINGS                                          1
# 2  01  ONE FAMILY DWELLINGS                                          1
# 3  01  ONE FAMILY DWELLINGS                                          1
# 4  01  ONE FAMILY DWELLINGS                                          1
#
#    BLOCK\n  LOT\n EASE-MENT\n BUILDING CLASS AT PRESENT\n  \
# 0     6360     22                                      A5
# 1     6361     17                                      A5
# 2     6371     60                                      A9
# 3     6372     48                                      S1
# 4     6373     73                                      A1
#
# ...

# %%
list(re_sales.columns)
# Out:
# ['BOROUGH\n',
#  'NEIGHBORHOOD\n',
#  'BUILDING CLASS CATEGORY\n',
#  'TAX CLASS AT PRESENT\n',
#  'BLOCK\n',
#  'LOT\n',
#  'EASE-MENT\n',
#  'BUILDING CLASS AT PRESENT\n',
#  'ADDRESS\n',
#  'APARTMENT NUMBER\n',
#  'ZIP CODE\n',
#  'RESIDENTIAL UNITS\n',
#  'COMMERCIAL UNITS\n',
#  'TOTAL UNITS\n',
#  'LAND SQUARE FEET\n',
#  'GROSS SQUARE FEET\n',
#  'YEAR BUILT\n',
#  'TAX CLASS AT TIME OF SALE\n',
#  'BUILDING CLASS AT TIME OF SALE\n',
#  'SALE PRICE\n',
#  'SALE DATE\n']

# %%
re_sales['SALE PRICE\n'].sum()
# Out:
# 19990077327

# %%
re_sales.describe()
# Out:
#        BOROUGH\n       BLOCK\n         LOT\n    ZIP CODE\n  \
# count    25362.0  25362.000000  25362.000000  25362.000000
# mean         3.0   4207.714534    281.084418  11217.017270
# min          3.0     20.000000      1.000000      0.000000
# 25%          3.0   1768.000000     21.000000  11209.000000
# 50%          3.0   4149.000000     46.000000  11219.000000
# 75%          3.0   6540.000000    103.000000  11231.000000
# max          3.0   8955.000000   9033.000000  11249.000000
# std          0.0   2649.487442    492.384071    186.770716
#
#        RESIDENTIAL UNITS\n  COMMERCIAL UNITS\n  TOTAL UNITS\n  \
# count         25362.000000        25362.000000   25362.000000
# mean              2.376981            0.185474       2.603817
# min               0.000000            0.000000       0.000000
# 25%               1.000000            0.000000       1.000000
# 50%               1.000000            0.000000       1.000000
# ...

# %%
re_sales['SALE PRICE\n'][re_sales['SALE PRICE\n']>0].mean()
# Out:
# 1236091.8455973286

# %%
re_sales['YEAR BUILT\n'].mean()
# Out:
# 1774.9955839444838

# %%
re_sales['YEAR BUILT\n'][re_sales['YEAR BUILT\n']>0].mean()
# Out:
# 1940.4068103448276

# %%
re_sales[['ZIP CODE\n','SALE PRICE\n']].groupby(by=['ZIP CODE\n']).mean()
# Out:
#             SALE PRICE\n
# ZIP CODE\n
# 0           4.892857e+05
# 11201       1.618065e+06
# 11203       4.190376e+05
# 11204       4.908219e+05
# 11205       7.062129e+05
# 11206       1.213060e+06
# 11207       4.006299e+05
# 11208       3.979557e+05
# 11209       5.333751e+05
# 11210       6.411172e+05
# 11211       1.272336e+06
# 11212       7.217267e+05
# 11213       7.467856e+05
# 11214       5.148053e+05
# 11215       1.200128e+06
# 11216       7.310867e+05
# 11217       1.619211e+06
# 11218       7.183455e+05
# 11219       4.863094e+05
# 11220       6.457887e+05
# 11221       5.739595e+05
# 11222       1.250622e+06
# 11223       6.056926e+05
# 11224       8.177449e+05
# 11225       1.114451e+06
# 11226       1.403538e+06
# 11227       6.000000e+05
# 11228       5.305021e+05
# 11229       4.220108e+05
# 11230       5.853335e+05
# 11231       1.539066e+06
# 11232       1.392873e+06
# 11233       5.631594e+05
# 11234       3.765121e+05
# 11235       4.385999e+05
# ...

# %%
len(re_sales['ZIP CODE\n'].unique())
# Out:
# 40

# %%
re_sales[['ZIP CODE\n','SALE PRICE\n']][re_sales['SALE PRICE\n']>0].groupby(by=['ZIP CODE\n']).mean()
# Out:
#             SALE PRICE\n
# ZIP CODE\n
# 0           1.141667e+06
# 11201       2.166831e+06
# 11203       6.429206e+05
# 11204       9.652831e+05
# 11205       1.301547e+06
# 11206       2.298876e+06
# 11207       6.359920e+05
# 11208       5.865420e+05
# 11209       7.335025e+05
# 11210       9.522476e+05
# 11211       2.207692e+06
# 11212       1.145288e+06
# 11213       1.282217e+06
# 11214       8.864119e+05
# 11215       1.677166e+06
# 11216       1.241408e+06
# 11217       2.331664e+06
# 11218       1.032427e+06
# 11219       9.543658e+05
# 11220       1.066721e+06
# 11221       8.860067e+05
# 11222       2.093432e+06
# 11223       1.035133e+06
# 11224       1.256970e+06
# 11225       1.690406e+06
# 11226       2.036889e+06
# 11227       1.200000e+06
# 11228       8.778093e+05
# 11229       6.480097e+05
# 11230       9.237294e+05
# 11231       2.541695e+06
# 11232       2.185370e+06
# 11233       8.741063e+05
# 11234       5.786560e+05
# 11235       6.236420e+05
# ...

# %%
re_sales[['ZIP CODE\n','SALE PRICE\n']].groupby(by=['ZIP CODE\n']).mean().sort_values(by='SALE PRICE\n', ascending= False).plot.bar()
# Out:
# <Axes: xlabel='ZIP CODE\n'>

# %%
re_sales[['ZIP CODE\n','SALE PRICE\n']][re_sales['SALE PRICE\n']>0].groupby(by=['ZIP CODE\n']).mean().sort_values(by='SALE PRICE\n', ascending= False).plot.bar()
# Out:
# <Axes: xlabel='ZIP CODE\n'>

# %%
re_sales[['ZIP CODE\n','SALE PRICE\n']].groupby(by=['ZIP CODE\n']).sum().sort_values(by='SALE PRICE\n', ascending= False)
# Out:
#             SALE PRICE\n
# ZIP CODE\n
# 11201         1986984263
# 11215         1202527889
# 11249          989082814
# 11238          914549280
# 11211          891907730
# 11217          816082437
# 11226          731243093
# 11206          657478647
# 11231          612548434
# 11221          588308438
# 11222          577787347
# 11216          567323271
# 11235          546934073
# 11205          538840478
# 11218          476981418
# 11223          448212521
# 11209          437900992
# 11233          427437986
# 11234          423576162
# 11230          413830767
# 11225          402316703
# 11207          396223004
# 11237          394197059
# 11214          385589160
# 11220          382952719
# 11232          380254462
# 11229          373901585
# 11219          355978454
# 11213          339787467
# 11210          323764186
# 11204          318543428
# 11208          303242226
# 11212          296629688
# 11224          287846195
# 11236          278109553
# ...

# %%
re_sales[['ZIP CODE\n','GROSS SQUARE FEET\n']].groupby(by=['ZIP CODE\n']).sum().sort_values(by='GROSS SQUARE FEET\n', ascending= False)
# Out:
#             GROSS SQUARE FEET\n
# ZIP CODE\n
# 11226                   3966000
# 11221                   3108606
# 11207                   2927931
# 11234                   2700847
# 11216                   2664038
# 11201                   2634291
# 11212                   2610589
# 11238                   2606097
# 11205                   2532107
# 11233                   2508819
# 11211                   2222272
# 11208                   2180869
# 11235                   2113837
# 11215                   2004753
# 11219                   1995328
# 11213                   1956397
# 11206                   1905171
# 11236                   1880580
# 11237                   1829927
# 11225                   1811767
# 11203                   1763658
# 11214                   1646208
# 11230                   1596758
# 11218                   1563861
# 11220                   1558903
# 11229                   1551479
# 11210                   1531604
# 11224                   1496847
# ...

# %% [markdown]
# ## DATASET 3
